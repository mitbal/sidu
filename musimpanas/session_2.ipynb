# %%
import numpy as np

# %%
a = np.random.uniform(size=(4, 3))
b = np.random.uniform(size=(3, 5))

# %%
# Implement matrix multiplication using for loop

def matmul_naive(a, b):
    
    dim1 = a.shape[0]
    dim2 = b.shape[1]
    dim3 = a.shape[1] # or b.shape[0]
    
    result = np.zeros((dim1, dim2))
    
    for i in range(dim1):
        for j in range(dim2):
            for k in range(dim3):
                
                result[i, j] += a[i, k] * b[k, j]
    
    return result

# %%
matmul_naive(a, b)
# Out:
# array([[1.24773963, 0.45542123, 0.5697045 , 1.53059284, 1.40419928],
#        [1.24595801, 0.26567444, 0.97238151, 1.2351754 , 0.7794002 ],
#        [0.63516498, 0.22766353, 0.27093937, 0.77223305, 0.70938369],
#        [1.75283235, 0.54134687, 1.00259865, 1.99742261, 1.65074439]])

# %%
# Implement matrix multiplication using numpy

# %%
np.matmul(a, b)
# Out:
# array([[1.24773963, 0.45542123, 0.5697045 , 1.53059284, 1.40419928],
#        [1.24595801, 0.26567444, 0.97238151, 1.2351754 , 0.7794002 ],
#        [0.63516498, 0.22766353, 0.27093937, 0.77223305, 0.70938369],
#        [1.75283235, 0.54134687, 1.00259865, 1.99742261, 1.65074439]])

# %%
# %%timeit 
matmul_naive(a, b)
# Out:
# 10000 loops, best of 3: 43.5 µs per loop

# %%
# %%timeit
np.matmul(a, b)
# Out:
# The slowest run took 14.15 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 1.31 µs per loop

# %%
# numpy is much, much faster
# this is become more apparent when the matrix size is big

# %%
a = np.random.normal(size=(500, 600))
b = np.random.normal(size=(600, 400))

# %%
# %%time

matmul_naive(a, b)
# Out:
# Wall time: 1min 12s
# array([[  6.83930987,   8.99344531,  -1.39155555, ...,  -1.73177889,
#          44.78692875, -20.23910077],
#        [-54.50630793,  21.52208159,  41.18173636, ..., -46.7135092 ,
#           6.31611549,  -1.14188006],
#        [  6.21827224, -26.35857983, -21.42965451, ..., -11.05237544,
#          -3.64613273, -22.66914618],
#        ...,
#        [ 39.87810924,   2.28996024, -19.19753826, ..., -14.53011893,
#         -13.5592842 , -20.01130235],
#        [  5.05356897,  -2.22032696, -22.14797224, ..., -38.24900704,
#         -10.00104824,  -2.66316652],
#        [ 28.52394834,  37.77030447,  22.39705948, ...,  31.05054183,
#         -59.21123444,  15.92287729]])

# %%
# %%time

np.matmul(a, b)
# Out:
# Wall time: 4 ms
# array([[  6.83930987,   8.99344531,  -1.39155555, ...,  -1.73177889,
#          44.78692875, -20.23910077],
#        [-54.50630793,  21.52208159,  41.18173636, ..., -46.7135092 ,
#           6.31611549,  -1.14188006],
#        [  6.21827224, -26.35857983, -21.42965451, ..., -11.05237544,
#          -3.64613273, -22.66914618],
#        ...,
#        [ 39.87810924,   2.28996024, -19.19753826, ..., -14.53011893,
#         -13.5592842 , -20.01130235],
#        [  5.05356897,  -2.22032696, -22.14797224, ..., -38.24900704,
#         -10.00104824,  -2.66316652],
#        [ 28.52394834,  37.77030447,  22.39705948, ...,  31.05054183,
#         -59.21123444,  15.92287729]])

# %%
# Special note, matrix exponentiation

# %%
# EXERCISE: implement nearest neighbour using only 2 loops, 1 loop, and no loop!!!

# %%
# Load dataset using pandas and calculate descriptive analytics

# %%
import pandas as pd

df = pd.read_csv('mysterious.csv')
df.head()
# Out:
#       feat1     feat2     feat3     feat4     feat5     feat6     feat7  \
# 0 -2.866301 -0.267440 -2.428004 -3.494560  0.871919  0.881505  3.816921
# 1 -2.139075 -2.470905 -0.057152 -2.150137 -2.044245 -0.697776  2.537400
# 2 -1.537203  1.556487 -2.590104 -1.405510  0.875863 -0.413090  0.491795
# 3 -1.720740  1.464458 -0.999263 -2.067171  0.087345 -0.474121 -0.781176
# 4 -0.518428 -1.096544 -0.157820  1.139586  1.343738  0.045450  1.398397
#
#       feat8     feat9    feat10  label
# 0 -3.946406 -0.101906  0.843183      0
# 1  2.046948  0.855529  1.413951      0
# 2 -1.170786  1.502454  1.839824      0
# 3  0.306227 -2.255987  1.373550      0
# 4  3.483335  0.859490  0.950258      0

# %%
df.describe()
# Out:
#              feat1        feat2        feat3        feat4        feat5  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.021745    -0.813600    -0.551513    -0.531797    -0.687085
# std       1.359975     1.857188     1.574492     1.528135     1.601335
# min      -3.849663    -6.808571    -6.072411    -6.093296    -5.546981
# 25%      -1.015739    -2.060002    -1.633307    -1.561568    -1.794843
# 50%       0.015719    -0.871803    -0.577392    -0.614114    -0.703362
# 75%       1.081936     0.379481     0.554187     0.450371     0.438892
# max       3.783423     6.196074     4.731596     4.820505     4.977969
#
#              feat6        feat7        feat8        feat9       feat10  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     -0.033635     0.678574    -2.581924    -0.923267    -0.023469
# std       1.090520     1.636654     3.476189     1.928777     1.311533
# min      -3.622500    -4.430747   -13.554524    -6.676707    -4.011914
# 25%      -0.748435    -0.448957    -5.003549    -2.236541    -1.050242
# 50%      -0.045657     0.654248    -2.575160    -0.960039     0.005086
# 75%       0.718104     1.739794    -0.166837     0.346063     1.001122
# max       3.633270     5.723107     8.328438     5.916945     4.141211
#
#              label
# count  2000.000000
# mean      0.500000
# std       0.500125
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %%
df.groupby('label').mean()
# Out:
#           feat1     feat2     feat3     feat4     feat5     feat6     feat7  \
# label
# 0     -0.987987 -0.851078 -0.551748 -0.546796 -0.733219 -0.053915  0.649276
# 1      1.031476 -0.776122 -0.551277 -0.516797 -0.640952 -0.013356  0.707873
#
#           feat8     feat9    feat10
# label
# 0     -2.542890 -0.930935  0.947002
# 1     -2.620957 -0.915599 -0.993939

# %%
df.corr()
# Out:
#            feat1     feat2     feat3     feat4     feat5     feat6     feat7  \
# feat1   1.000000 -0.006628  0.001974  0.007166  0.019438  0.030100  0.027433
# feat2  -0.006628  1.000000 -0.031749 -0.007174 -0.011260  0.002801  0.013964
# feat3   0.001974 -0.031749  1.000000  0.018605 -0.000143 -0.017705  0.017776
# feat4   0.007166 -0.007174  0.018605  1.000000 -0.025901 -0.050999 -0.002503
# feat5   0.019438 -0.011260 -0.000143 -0.025901  1.000000  0.005751  0.023208
# feat6   0.030100  0.002801 -0.017705 -0.050999  0.005751  1.000000 -0.018542
# feat7   0.027433  0.013964  0.017776 -0.002503  0.023208 -0.018542  1.000000
# feat8  -0.028254  0.007517  0.013652  0.003215 -0.009946  0.006133 -0.025829
# feat9   0.018318 -0.000400  0.014048 -0.008472 -0.016019  0.003258 -0.008032
# feat10 -0.555003  0.006928  0.007097 -0.024659 -0.030462 -0.025175 -0.018838
# label   0.742649  0.020185  0.000150  0.009818  0.028817  0.018601  0.017906
#
#            feat8     feat9    feat10     label
# feat1  -0.028254  0.018318 -0.555003  0.742649
# feat2   0.007517 -0.000400  0.006928  0.020185
# feat3   0.013652  0.014048  0.007097  0.000150
# feat4   0.003215 -0.008472 -0.024659  0.009818
# feat5  -0.009946 -0.016019 -0.030462  0.028817
# feat6   0.006133  0.003258 -0.025175  0.018601
# feat7  -0.025829 -0.008032 -0.018838  0.017906
# feat8   1.000000 -0.006556  0.035877 -0.011232
# feat9  -0.006556  1.000000  0.013973  0.003976
# feat10  0.035877  0.013973  1.000000 -0.740136
# label  -0.011232  0.003976 -0.740136  1.000000

# %%
# Let's visualize the dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.heatmap(df.corr(), cmap='Blues')

# %%
# scatter plot, matplotlib version

fig, ax = plt.subplots(figsize=(10, 10))

ax.scatter(df['feat1'], df['feat2'])

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.scatter(df[df['label'] == 0]['feat2'], df[df['label'] == 0]['feat3'])
ax.scatter(df[df['label'] == 1]['feat2'], df[df['label'] == 1]['feat3'])

# %%
# scatter plot, seaborn version
fig, ax = plt.subplots(figsize=(10, 10))

sns.scatterplot(x='feat3', y='feat4', data=df, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.scatterplot(x='feat4', y='feat5', hue='label', data=df, ax=ax)

# %%
# distribution plot, histogram, kde, boxplot, swarmplot

# %%
sns.distplot(df['feat1'])
# Out:
# C:\Users\mitbal\Anaconda2\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df['feat2'], kde=False)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='label', vars=['feat1', 'feat3', 'feat6', 'feat8'])

# %%
sns.boxplot(y='label', x='feat4', data=df)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

sns.violinplot(x='label', y='feat7', data=df.sample(100), ax=ax)
sns.swarmplot(x='label', y='feat7', data=df.sample(100), ax=ax, color='white')

# %%
# subplots for creating multiple plots and customising them

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 10))

ax = axes[0]
sns.violinplot(x='label', y='feat7', data=df.sample(100), ax=ax)

ax = axes[1]
sns.swarmplot(x='label', y='feat7', data=df.sample(100), ax=ax)

ax = axes[2]
sns.boxplot(x='label', y='feat7', data=df.sample(100), ax=ax)
